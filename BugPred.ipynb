# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaftab/bugPridiction/blob/main/BugPred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
cd '/content/drive/MyDrive/softwareBugPred'
# Out:
# /content/drive/MyDrive/softwareBugPred

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/softwareBugPred'

# %%
# !which python # should return /usr/local/bin/python
# Out:
# /usr/local/bin/python

# %%
# !python --version
# Out:
# Python 3.7.10

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.6.14-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# reinstalling: python-3.7.3-h0371630_0 ...
# using -f (force) option
# Python 3.7.3
# reinstalling: ca-certificates-2019.1.23-0 ...
# using -f (force) option
# reinstalling: libgcc-ng-8.2.0-hdf63c60_1 ...
# using -f (force) option
# reinstalling: libstdcxx-ng-8.2.0-hdf63c60_1 ...
# using -f (force) option
# reinstalling: libffi-3.2.1-hd88cf55_4 ...
# using -f (force) option
# reinstalling: ncurses-6.1-he6710b0_1 ...
# using -f (force) option
# reinstalling: openssl-1.1.1b-h7b6447c_1 ...
# using -f (force) option
# reinstalling: xz-5.2.4-h14c3975_4 ...
# using -f (force) option
# reinstalling: yaml-0.1.7-had09818_2 ...
# using -f (force) option
# reinstalling: zlib-1.2.11-h7b6447c_3 ...
# using -f (force) option
# reinstalling: libedit-3.1.20181209-hc058e9b_0 ...
# using -f (force) option
# reinstalling: readline-7.0-h7b6447c_5 ...
# using -f (force) option
# reinstalling: tk-8.6.8-hbc83047_0 ...
# using -f (force) option
# ...

# %%
# !which conda # should return /usr/local/bin/conda
# Out:
# /usr/local/bin/conda

# %%
# !conda --version # should return 4.5.4
# Out:
# conda 4.6.14

# %%
# !which python # still returns /usr/local/bin/python
# Out:
# /usr/local/bin/python

# %%
# !python --version
# Out:
# Python 3.7.3

# %%
# %%bash
# conda install --channel defaults conda python=3.7 --yes
# conda update --channel defaults --all --yes
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |             main           3 KB
#     ca-certificates-2021.5.25  |       h06a4308_1         118 KB
#     certifi-2021.5.30          |   py37h06a4308_0         141 KB
#     cffi-1.14.5                |   py37h261ae71_0         224 KB
#     conda-4.10.1               |   py37h06a4308_1         3.1 MB
#     conda-package-handling-1.7.3|   py37h27cfd23_1         962 KB
#     ld_impl_linux-64-2.35.1    |       h7274673_9         637 KB
#     libffi-3.3                 |       he6710b0_2          54 KB
#     ncurses-6.2                |       he6710b0_1         1.1 MB
#     openssl-1.1.1k             |       h27cfd23_0         3.8 MB
# ...

# %%
# !conda --version
# Out:
# conda 4.10.1

# %%
# !python --version
# Out:
# Python 3.7.10

# %%
import sys
sys.path
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# !ls /usr/local/lib/python3.7/dist-packages
# Out:
# absl
# absl_py-0.12.0.dist-info
# alabaster
# alabaster-0.7.12.dist-info
# albumentations
# albumentations-0.1.12.dist-info
# altair
# altair-4.1.0.dist-info
# apiclient
# appdirs-1.4.4.dist-info
# appdirs.py
# apt
# apt_inst.cpython-37m-x86_64-linux-gnu.so
# apt_inst.pyi
# apt_pkg.cpython-37m-x86_64-linux-gnu.so
# apt_pkg.pyi
# aptsources
# argon2
# argon2_cffi-20.1.0.dist-info
# arviz
# arviz-0.11.2.dist-info
# astor
# astor-0.8.1.dist-info
# astropy
# astropy-4.2.1.dist-info
# astunparse
# astunparse-1.6.3.dist-info
# async_generator
# async_generator-1.10.dist-info
# atari_py
# atari_py-0.2.9.dist-info
# atari_py.libs
# atomicwrites
# atomicwrites-1.4.0.dist-info
# attr
# attrs-21.2.0.dist-info
# audioread
# audioread-2.1.9.dist-info
# autograd
# autograd-1.3.dist-info
# babel
# Babel-2.9.1.dist-info
# backcall
# backcall-0.2.0.dist-info
# beautifulsoup4-4.6.3.dist-info
# bin
# bleach
# bleach-3.3.0.dist-info
# blis
# blis-0.4.1.dist-info
# bokeh
# bokeh-2.3.2.dist-info
# ...

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.7/site-packages"))

# %%
# !conda install --channel conda-forge featuretools --yes
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - featuretools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bokeh-2.3.2                |   py37h89c1867_0         8.3 MB  conda-forge
#     ca-certificates-2021.5.30  |       ha878542_0         136 KB  conda-forge
#     certifi-2021.5.30          |   py37h89c1867_0         141 KB  conda-forge
#     click-8.0.1                |   py37h89c1867_0         145 KB  conda-forge
#     cloudpickle-1.6.0          |             py_0          22 KB  conda-forge
#     conda-4.10.1               |   py37h89c1867_0         3.1 MB  conda-forge
#     cytoolz-0.11.0             |   py37h5e8e339_3         403 KB  conda-forge
#     dask-2021.6.1              |     pyhd8ed1ab_0           4 KB  conda-forge
# ...

# %%
# !conda install -c conda-forge scikit-learn
# Out:
# done
# done

# %%
# !scikit-learn --version
# Out:
# /bin/bash: scikit-learn: command not found

# %%
# !conda install -c conda-forge scipy

# %%
# !conda install matplotlib
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.5.25  |       h06a4308_1         112 KB
#     certifi-2021.5.30          |   py37h06a4308_0         139 KB
#     conda-4.10.1               |   py37h06a4308_1         2.9 MB
#     cycler-0.10.0              |           py37_0          13 KB
#     dbus-1.13.18               |       hb2f20db_0         504 KB
#     expat-2.4.1                |       h2531618_2         168 KB
#     fontconfig-2.13.1          |       h6c09931_0         250 KB
#     glib-2.68.2                |       h36276a3_0         3.0 MB
#     gst-plugins-base-1.14.0    |       h8213a91_2         4.9 MB
#     gstreamer-1.14.0           |       h28cd5cc_2         3.2 MB
# ...

# %%
# !git clone https://github.com/Gaftab/bugPridiction.git
# Out:
# Cloning into 'bugPridiction'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 26 (delta 3), reused 22 (delta 2), pack-reused 0
# Unpacking objects: 100% (26/26), done.

# %%
! conda install

# %%
# %run /content/drive/MyDrive/softwareBugPred/bugPridiction/code/classifier/softwareBug_clfs_cm1.py
# Out:
# svm cross validation scores  [0.9        0.9        0.9        0.9        0.9        0.9
#  0.9        0.9        0.91836735 0.89795918]
# svm cross validation scores  [0.9        0.9        0.9        0.9        0.9        0.9
#  0.9        0.9        0.91836735 0.89795918]
# LogisticRegression cross validation scores  [0.88       0.9        0.9        0.92       0.9        0.9
#  0.9        0.88       0.91836735 0.89795918]
# LogisticRegression cross validation scores  [0.88       0.9        0.9        0.92       0.9        0.9
#  0.9        0.88       0.91836735 0.89795918]
# RandomForestClassifier cross validation scores  [0.9        0.9        0.92       0.9        0.9        0.9
#  0.88       0.9        0.91836735 0.89795918]
# RandomForestClassifier cross validation scores  [0.88       0.9        0.9        0.9        0.9        0.9
#  0.88       0.9        0.93877551 0.89795918]
# ...

# %%
# %run /content/drive/MyDrive/softwareBugPred/bugPridiction/code/classifier/softwareBug_clfs_pc1.py
# Out:
# svm cross validation scores  [0.94594595 0.93693694 0.93693694 0.92792793 0.91891892 0.93693694
#  0.92792793 0.92792793 0.92792793 0.93636364]
# svm cross validation scores  [0.94594595 0.93693694 0.93693694 0.92792793 0.91891892 0.93693694
#  0.92792793 0.92792793 0.92792793 0.93636364]
# LogisticRegression cross validation scores  [0.95495495 0.92792793 0.91891892 0.91891892 0.92792793 0.92792793
#  0.92792793 0.92792793 0.92792793 0.93636364]
# LogisticRegression cross validation scores  [0.95495495 0.92792793 0.91891892 0.91891892 0.92792793 0.92792793
#  0.92792793 0.92792793 0.92792793 0.93636364]
# RandomForestClassifier cross validation scores  [0.93693694 0.91891892 0.92792793 0.91891892 0.90990991 0.87387387
#  0.94594595 0.95495495 0.97297297 0.95454545]
# RandomForestClassifier cross validation scores  [0.92792793 0.93693694 0.92792793 0.92792793 0.90990991 0.87387387
#  0.94594595 0.95495495 0.97297297 0.95454545]
# ...

# %%
# %run /content/drive/MyDrive/softwareBugPred/bugPridiction/code/classifier/softwareBug_clfs_PC3.py
# Out:
# svm cross validation scores  [0.89808917 0.89808917 0.89808917 0.8974359  0.8974359  0.8974359
#  0.8974359  0.8974359  0.8974359  0.8974359 ]
# svm cross validation scores  [0.89808917 0.89808917 0.89808917 0.8974359  0.8974359  0.8974359
#  0.8974359  0.8974359  0.8974359  0.8974359 ]
# LogisticRegression cross validation scores  [0.9044586  0.9044586  0.89808917 0.87820513 0.89102564 0.8974359
#  0.89102564 0.8974359  0.88461538 0.90384615]
# LogisticRegression cross validation scores  [0.9044586  0.9044586  0.89808917 0.87820513 0.89102564 0.8974359
#  0.89102564 0.8974359  0.88461538 0.90384615]
# RandomForestClassifier cross validation scores  [0.92356688 0.89808917 0.9044586  0.86538462 0.90384615 0.8974359
#  0.8974359  0.91025641 0.91666667 0.91666667]
# RandomForestClassifier cross validation scores  [0.91719745 0.9044586  0.89808917 0.86538462 0.91025641 0.8974359
#  0.8974359  0.90384615 0.90384615 0.8974359 ]
# ...

# %%
# %run /content/drive/MyDrive/softwareBugPred/bugPridiction/code/classifier/softwareBug_clfs_kc2.py
# Out:
# svm cross validation scores  [0.94339623 0.86792453 0.82692308 0.88461538 0.90384615 0.84615385
#  0.82692308 0.73076923 0.73076923 0.75      ]
# svm cross validation scores  [0.94339623 0.86792453 0.82692308 0.88461538 0.90384615 0.84615385
#  0.82692308 0.73076923 0.73076923 0.75      ]
# LogisticRegression cross validation scores  [0.94339623 0.88679245 0.82692308 0.84615385 0.86538462 0.82692308
#  0.80769231 0.76923077 0.76923077 0.78846154]
# LogisticRegression cross validation scores  [0.94339623 0.88679245 0.82692308 0.84615385 0.86538462 0.82692308
#  0.80769231 0.76923077 0.76923077 0.78846154]
# RandomForestClassifier cross validation scores  [0.9245283  0.94339623 0.65384615 0.86538462 0.84615385 0.82692308
#  0.78846154 0.73076923 0.65384615 0.75      ]
# RandomForestClassifier cross validation scores  [0.90566038 0.9245283  0.65384615 0.88461538 0.82692308 0.84615385
#  0.82692308 0.75       0.69230769 0.75      ]
# ...

# %%
# %run /content/drive/MyDrive/softwareBugPred/bugPridiction/code/classifier/softwareBug_clfs_kc1.py
# Out:
# svm cross validation scores  [0.85308057 0.86729858 0.8436019  0.8436019  0.82464455 0.83886256
#  0.8436019  0.85308057 0.85308057 0.89047619]
# svm cross validation scores  [0.85308057 0.86729858 0.8436019  0.8436019  0.82464455 0.83886256
#  0.8436019  0.85308057 0.85308057 0.89047619]
# LogisticRegression cross validation scores  [0.85781991 0.85308057 0.83886256 0.82938389 0.83886256 0.82938389
#  0.86255924 0.86729858 0.86255924 0.9       ]
# LogisticRegression cross validation scores  [0.85781991 0.85308057 0.83886256 0.82938389 0.83886256 0.82938389
#  0.86255924 0.86729858 0.86255924 0.9       ]
# RandomForestClassifier cross validation scores  [0.85781991 0.77251185 0.84834123 0.85308057 0.79620853 0.81042654
#  0.81042654 0.85781991 0.81990521 0.89047619]
# RandomForestClassifier cross validation scores  [0.84834123 0.76777251 0.84834123 0.8436019  0.79146919 0.8056872
#  0.81042654 0.84834123 0.80094787 0.9       ]
# ...

# %%
# %run /content/drive/MyDrive/softwareBugPred/bugPridiction/code/classifier/test.py

# %% [markdown]
# GIT Portion to control versions of work

# %%
# %cd '/content/drive/MyDrive/softwareBugPred/bugPridiction'
# Out:
# /content/drive/MyDrive/softwareBugPred/bugPridiction

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/softwareBugPred/bugPridiction/.git/

# %%
# !git remote add origin https://Gaftab:aftab12345facebook@github.com/Gaftab/bugPridiction.git

# %%
# !git remote remove origin

# %%
# !git remote -v
# Out:
# origin	https://Gaftab:aftab12345facebook@github.com/Gaftab/bugPridiction.git (fetch)
# origin	https://Gaftab:aftab12345facebook@github.com/Gaftab/bugPridiction.git (push)

# %%
! git config --global user.email 'aftabbaig328@gmail.com'
! git config --global user.name 'Gaftab'

# %%
# !git status
# Out:
# On branch main
# nothing to commit, working tree clean

# %%
! git add .
# !git commit -m 'code has modified'
# Out:
# On branch main
# nothing to commit, working tree clean

# %%
# !git fetch origin main
# Out:
# From https://github.com/Gaftab/bugPridiction
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
# !git push origin main
# Out:
# Counting objects: 10, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (10/10), 3.04 KiB | 388.00 KiB/s, done.
# Total 10 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 1 local object.
# To https://github.com/Gaftab/bugPridiction.git
#    e67f771..2b95390  main -> main
